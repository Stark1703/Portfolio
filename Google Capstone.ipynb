# %%
import pandas as pd
import matplotlib
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import statistics as stats

# %%
#finding the current working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\Catherine'

# %%
tripdata_2020_04 = pd.read_csv('C:\\Users\\Catherine\\Desktop\\cycling\\202004-divvy-tripdata.csv')
tripdata_2020_04.head()
# Out:
#             ride_id rideable_type        started_at          ended_at  \
# 0  A847FADBBC638E45   docked_bike   4/26/2020 17:45   4/26/2020 18:12
# 1  5405B80E996FF60D   docked_bike   4/17/2020 17:08   4/17/2020 17:17
# 2  5DD24A79A4E006F4   docked_bike  04-01-2020 17:54  04-01-2020 18:08
# 3  2A59BBDF5CDBA725   docked_bike  04-07-2020 12:50  04-07-2020 13:02
# 4  27AD306C119C6158   docked_bike   4/18/2020 10:22   4/18/2020 11:15
#
#              start_station_name  start_station_id  \
# 0                  Eckhart Park                86
# 1     Drake Ave & Fullerton Ave               503
# 2          McClurg Ct & Erie St               142
# 3  California Ave & Division St               216
# 4          Rush St & Hubbard St               125
#
#               end_station_name  end_station_id  start_lat  start_lng  end_lat  \
# 0  Lincoln Ave & Diversey Pkwy           152.0    41.8964   -87.6610  41.9322
# 1              Kosciuszko Park           499.0    41.9244   -87.7154  41.9306
# ...

# %%
tripdata_2020_05 = pd.read_csv('C:\\Users\\Catherine\\Desktop\\cycling\\202005-divvy-tripdata.csv')
tripdata_2020_05.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  02668AD35674B983   docked_bike  2020-05-27 10:03:52  2020-05-27 10:16:49
# 1  7A50CCAF1EDDB28F   docked_bike  2020-05-25 10:47:11  2020-05-25 11:05:40
# 2  2FFCDFDB91FE9A52   docked_bike  2020-05-02 14:11:03  2020-05-02 15:48:21
# 3  58991CF1DB75BA84   docked_bike  2020-05-02 16:25:36  2020-05-02 16:39:28
# 4  A79651EFECC268CD   docked_bike  2020-05-29 12:49:54  2020-05-29 13:27:11
#
#            start_station_name  start_station_id  \
# 0  Franklin St & Jackson Blvd                36
# 1   Clark St & Wrightwood Ave               340
# 2  Kedzie Ave & Milwaukee Ave               260
# 3  Clarendon Ave & Leland Ave               251
# 4     Hermitage Ave & Polk St               261
#
#                  end_station_name  end_station_id  start_lat  start_lng  \
# 0          Wabash Ave & Grand Ave           199.0    41.8777   -87.6353
# ...

# %%
tripdata_2020_06 = pd.read_csv('C:\\Users\\Catherine\\Desktop\\cycling\\202006-divvy-tripdata.csv')
tripdata_2020_06.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  8CD5DE2C2B6C4CFC   docked_bike  2020-06-13 23:24:48  2020-06-13 23:36:55
# 1  9A191EB2C751D85D   docked_bike  2020-06-26 07:26:10  2020-06-26 07:31:58
# 2  F37D14B0B5659BCF   docked_bike  2020-06-23 17:12:41  2020-06-23 17:21:14
# 3  C41237B506E85FA1   docked_bike  2020-06-20 01:09:35  2020-06-20 01:28:24
# 4  4B51B3B0BDA7787C   docked_bike  2020-06-25 16:59:25  2020-06-25 17:08:48
#
#             start_station_name  start_station_id          end_station_name  \
# 0     Wilton Ave & Belmont Ave               117  Damen Ave & Clybourn Ave
# 1         Federal St & Polk St                41        Daley Center Plaza
# 2           Daley Center Plaza                81    State St & Harrison St
# 3      Broadway & Cornelia Ave               303     Broadway & Berwyn Ave
# 4  Sheffield Ave & Webster Ave               327  Wilton Ave & Belmont Ave
#
# ...

# %%
tripdata_2020_07 = pd.read_csv('C:\\Users\\Catherine\\Desktop\\cycling\\202007-divvy-tripdata.csv')
tripdata_2020_07.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0
head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  E19E6F1B8D4C42ED  electric_bike  2021-01-23 16:14:19  2021-01-23 16:24:44
# 1  DC88F20C2C55F27F  electric_bike  2021-01-27 18:43:08  2021-01-27 18:47:12
# 2  EC45C94683FE3F27  electric_bike  2021-01-21 22:35:54  2021-01-21 22:37:14
# 3  4FA453A75AE377DB  electric_bike  2021-01-07 13:31:13  2021-01-07 13:42:55
# 4  BE5E8EB4E7263A0B  electric_bike  2021-01-23 02:24:02  2021-01-23 02:24:45
#
#            start_station_name start_station_id end_station_name  \
# 0  California Ave & Cortez St            17660              NaN
# 1  California Ave & Cortez St            17660              NaN
# 2  California Ave & Cortez St            17660              NaN
# 3  California Ave & Cortez St            17660              NaN
# 4  California Ave & Cortez St            17660              NaN
#
#   end_station_id  start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
tripdata_2021_02 = pd.read_csv('C:\\Users\\Catherine\\Desktop\\cycling\\202102-divvy-tripdata.csv')
tripdata_2021_02.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  89E7AA6C29227EFF   classic_bike  2021-02-12 16:14:56  2021-02-12 16:21:43
# 1  0FEFDE2603568365   classic_bike  2021-02-14 17:52:38  2021-02-14 18:12:09
# 2  E6159D746B2DBB91  electric_bike  2021-02-09 19:10:18  2021-02-09 19:19:10
# 3  B32D3199F1C2E75B   classic_bike  2021-02-02 17:49:41  2021-02-02 17:54:06
# 4  83E463F23575F4BF  electric_bike  2021-02-23 15:07:23  2021-02-23 15:22:37
#
#          start_station_name start_station_id            end_station_name  \
# 0  Glenwood Ave & Touhy Ave              525  Sheridan Rd & Columbia Ave
# 1  Glenwood Ave & Touhy Ave              525    Bosworth Ave & Howard St
# 2        Clark St & Lake St     KA1503000012      State St & Randolph St
# 3     Wood St & Chicago Ave              637     Honore St & Division St
# 4        State St & 33rd St            13216       Emerald Ave & 31st St
#
# ...

# %%
tripdata_2021_03 = pd.read_csv('C:\\Users\\Catherine\\Desktop\\cycling\\202103-divvy-tripdata.csv')
tripdata_2021_03.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  CFA86D4455AA1030  classic_bike  2021-03-16 08:32:30  2021-03-16 08:36:34
# 1  30D9DC61227D1AF3  classic_bike  2021-03-28 01:26:28  2021-03-28 01:36:55
# 2  846D87A15682A284  classic_bike  2021-03-11 21:17:29  2021-03-11 21:33:53
# 3  994D05AA75A168F2  classic_bike  2021-03-11 13:26:42  2021-03-11 13:55:41
# 4  DF7464FBE92D8308  classic_bike  2021-03-21 09:09:37  2021-03-21 09:27:33
#
#              start_station_name start_station_id  \
# 0  Humboldt Blvd & Armitage Ave            15651
# 1  Humboldt Blvd & Armitage Ave            15651
# 2         Shields Ave & 28th Pl            15443
# 3   Winthrop Ave & Lawrence Ave     TA1308000021
# 4      Glenwood Ave & Touhy Ave              525
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0              Stave St & Armitage Ave          13266  41.917513 -87.701809
# ...

# %%
bike_share = pd.concat([tripdata_2020_04, tripdata_2020_05, tripdata_2020_06, tripdata_2020_07, tripdata_2020_08, tripdata_2020_09, tripdata_2020_10,tripdata_2020_11,tripdata_2020_12,tripdata_2021_01,tripdata_2021_02,tripdata_2021_03])

# %%
bike_share.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3489748 entries, 0 to 228495
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: float64(4), object(9)
# memory usage: 372.7+ MB

# %%
bike_share['start_station_id'] = bike_share['start_station_id'].apply(str)


bike_share['end_station_id'] = bike_share['start_station_id'].apply(str)


bike_share['start_station_id'].dtype


bike_share['end_station_id'].dtype
# Out:
# dtype('O')

# %%
bike_share.head()
# Out:
#             ride_id rideable_type        started_at          ended_at  \
# 0  A847FADBBC638E45   docked_bike   4/26/2020 17:45   4/26/2020 18:12
# 1  5405B80E996FF60D   docked_bike   4/17/2020 17:08   4/17/2020 17:17
# 2  5DD24A79A4E006F4   docked_bike  04-01-2020 17:54  04-01-2020 18:08
# 3  2A59BBDF5CDBA725   docked_bike  04-07-2020 12:50  04-07-2020 13:02
# 4  27AD306C119C6158   docked_bike   4/18/2020 10:22   4/18/2020 11:15
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
#   end_station_id  start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
bike_share.isna().sum()
# Out:
# ride_id                    0
# rideable_type              0
# started_at                 0
# ended_at                   0
# start_station_name    122175
# start_station_id           0
# end_station_name      143242
# end_station_id             0
# start_lat                  0
# start_lng                  0
# end_lat                 4738
# end_lng                 4738
# member_casual              0
# dtype: int64

# %%
bike_share.shape
# Out:
# (3489748, 13)

# %%
(bike_share.isna().sum()/3489748) * 100
# Out:
# ride_id               0.000000
# rideable_type         0.000000
# started_at            0.000000
# ended_at              0.000000
# start_station_name    3.500969
# start_station_id      0.000000
# end_station_name      4.104652
# end_station_id        0.000000
# start_lat             0.000000
# start_lng             0.000000
# end_lat               0.135769
# end_lng               0.135769
# member_casual         0.000000
# dtype: float64

# %%
bike_share.dropna(axis=0, inplace=True)

# %%
bike_share.isna().sum()
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
bike_share[bike_share.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual]
# Index: []

# %%
# Let's convert columns 'started_at' and 'ended_at' to 'datetime' Datatype.

bike_share['started_at'] = pd.to_datetime(bike_share['started_at'], dayfirst = True)


bike_share['ended_at'] = pd.to_datetime(bike_share['ended_at'], dayfirst = True)

# %%
bike_share.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3295563 entries, 0 to 228494
# Data columns (total 13 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 352.0+ MB

# %%
bike_share['Hour'] = bike_share.started_at.apply(lambda x: x.hour)


bike_share['Day'] = bike_share.started_at.apply(lambda x: x.day_name())



bike_share['Month'] = bike_share.started_at.apply(lambda x: x.month)


bike_share.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:00 2020-04-26 18:12:00
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:00 2020-04-17 17:17:00
# 2  5DD24A79A4E006F4   docked_bike 2020-01-04 17:54:00 2020-01-04 18:08:00
# 3  2A59BBDF5CDBA725   docked_bike 2020-07-04 12:50:00 2020-07-04 13:02:00
# 4  27AD306C119C6158   docked_bike 2020-04-18 10:22:00 2020-04-18 11:15:00
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
# ...

# %%
import datetime as datetime

from datetime import timedelta

# %%
# Let's calculate 'Total_Ride_Time' in minutes.


bike_share['Total_Ride_Time'] = (bike_share['ended_at'] - bike_share['started_at'])


bike_share['Total_Ride_Time'] = (bike_share['Total_Ride_Time'])/timedelta(minutes=1)


bike_share['Total_Ride_Time'] = bike_share['Total_Ride_Time'].round(decimals = 1)


bike_share.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:00 2020-04-26 18:12:00
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:00 2020-04-17 17:17:00
# 2  5DD24A79A4E006F4   docked_bike 2020-01-04 17:54:00 2020-01-04 18:08:00
# 3  2A59BBDF5CDBA725   docked_bike 2020-07-04 12:50:00 2020-07-04 13:02:00
# 4  27AD306C119C6158   docked_bike 2020-04-18 10:22:00 2020-04-18 11:15:00
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
# ...

# %%
# Let's calculate the ride distance in Kms from given coordinates

bike_share['Lat'] = (bike_share['end_lat'] - bike_share['start_lat'])


bike_share['Lng'] = (bike_share['end_lng']) - bike_share['start_lng']


import math


bike_share['Distance'] = np.sqrt((bike_share['Lat']** 2) + (bike_share['Lng'] ** 2))


bike_share['Distance'] = bike_share['Distance'] * 111


bike_share['Distance'].head()
# Out:
# 0    3.982720
# 1    1.158874
# 2    3.006379
# 3    2.839800
# 4    9.353514
# Name: Distance, dtype: float64

# %%
bike_share['Distance'] = bike_share['Distance'].round(decimals = 2)
bike_share.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:00 2020-04-26 18:12:00
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:00 2020-04-17 17:17:00
# 2  5DD24A79A4E006F4   docked_bike 2020-01-04 17:54:00 2020-01-04 18:08:00
# 3  2A59BBDF5CDBA725   docked_bike 2020-07-04 12:50:00 2020-07-04 13:02:00
# 4  27AD306C119C6158   docked_bike 2020-04-18 10:22:00 2020-04-18 11:15:00
#
#              start_station_name start_station_id             end_station_name  \
# 0                  Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1     Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2          McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
# 3  California Ave & Division St              216       Wood St & Augusta Blvd
# 4          Rush St & Hubbard St              125   Sheridan Rd & Lawrence Ave
#
# ...

# %%
month = {1:'January', 2:'February', 3:'March', 4:'April', 5:'May', 6:'June', 7:'July', 8:'August', 9:'September', 10:'October', 11:'November', 12:'December'}

bike_share['Month_Name'] = bike_share['Month'].map(month)

bike_share['Month_Name'].head()
# Out:
# 0      April
# 1      April
# 2    January
# 3       July
# 4      April
# Name: Month_Name, dtype: object

# %%
# Data Analysis and Visualization

sns.set_style('whitegrid')

bike_share.head(3)
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  A847FADBBC638E45   docked_bike 2020-04-26 17:45:00 2020-04-26 18:12:00
# 1  5405B80E996FF60D   docked_bike 2020-04-17 17:08:00 2020-04-17 17:17:00
# 2  5DD24A79A4E006F4   docked_bike 2020-01-04 17:54:00 2020-01-04 18:08:00
#
#           start_station_name start_station_id             end_station_name  \
# 0               Eckhart Park               86  Lincoln Ave & Diversey Pkwy
# 1  Drake Ave & Fullerton Ave              503              Kosciuszko Park
# 2       McClurg Ct & Erie St              142   Indiana Ave & Roosevelt Rd
#
#   end_station_id  start_lat  start_lng  ...  end_lng  member_casual Hour  \
# 0             86    41.8964   -87.6610  ... -87.6586         member   17
# 1            503    41.9244   -87.7154  ... -87.7238         member   17
# 2            142    41.8945   -87.6179  ... -87.6230         member   17
#
# ...

# %%
sns.barplot(x='member_casual', y='Distance', data=bike_share, palette='rocket_r')
# Out:
# <AxesSubplot: xlabel='member_casual', ylabel='Distance'>

# %%
sns.barplot(x='member_casual', y='Total_Ride_Time', data=bike_share, palette='rocket_r')
# Out:
# <AxesSubplot: xlabel='member_casual', ylabel='Total_Ride_Time'>

# %%
plt.figure(figsize=(14,7))

sns.countplot(x='Hour', hue='member_casual', data=bike_share, palette='crest')
# Out:
# <AxesSubplot: xlabel='Hour', ylabel='count'>

# %%
plt.figure(figsize=(14,7))

order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

sns.countplot(x='Day', hue='member_casual', data=bike_share, palette='mako', order=order)

# Casual riders are enthuasiatic on weekends as they have the highest bike usage on Saturday and Sunday

# Member riders have consistent use of bikes on weekdays
# Out:
# <AxesSubplot: xlabel='Day', ylabel='count'>

# %%
plt.figure(figsize=(14,7))


order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November','December']


sns.countplot(x='Month_Name', hue='member_casual', data=bike_share, palette='cubehelix', order=order)



# The summer months show the highest usage of bikes. This can be a starting point for preparing business strategy.
# Out:
# <AxesSubplot: xlabel='Month_Name', ylabel='count'>

# %%
#  The bike usage trend highlightes the purpose for which the bikes are used.

"""from ipaddress import summarize_address_range
from tokenize import Special


Member riders have annual memberships because their frequency of bike usage is higher. They use it for daily commute of shorter distance.

      Casual riders more often use bikes for leisure or personal activities. Their usage is higher on weekends.

      summarize_address_range months are more popular and business can focus on this period to maximise its profit.

     Special 'Summer Membership' can be introduced specifically for casual riders who're hesitant to go for annual membership.

     Coupons, Discounts schemes can be introduced for casual riders to increase their bike usage on weekdays or small distance journeys.

 It is important for business to develop the idea of using bikes regulary than just for leisure activities in casual riders"""
